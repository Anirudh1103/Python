# %%
#Scikit-learn is a free machine learning library for python.

# %%
#Write a puthon program to load the iris data from a given csv file into a dataframe and print the shape of the data,
#type of the data and first 3 rows
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('iris.csv')
print("Shape of the data:")
print(data.shape)
print("Type of the data: ")
print(type(data))
print(data.head(3))
# Out:
# Shape of the data:
# (150, 6)
# Type of the data:
# <class 'pandas.core.frame.DataFrame'>
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
#Write a python program using Scikit-learn to print the keys, no of rows-columns feature names and description of the iris data
print("Keys of the iris data: ")
print(data.keys())
print("Rows-Colums of iris data")
print(data.shape)
# Out:
# Keys of the iris data:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
# Rows-Colums of iris data
# (150, 6)

# %%
#Write a python program to get the number of observations, missing values and nan values 
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
#Write a python program to view basic statistical details like percentile, mean etc of iris data
print(data.describe())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#Write a python program to access first four cells from given dataframe using the index and columns labels.
#call iris.csv to create the dataframe
print("Original data: ")
print(data.head())
new_data = data.drop('Id',axis = 1)
print("Data after removing the column id:")
print(new_data.head())
x = data.iloc[:,[1,2,3,4]].values
print(x)
# Out:
# Original data:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# Data after removing the column id:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
# [[5.1 3.5 1.4 0.2]
# ...

# %%
#Write a python program to create a general statistics of iris data.
data.describe().plot(kind = 'area',colormap = "Accent")
# Out:
# <Axes: >

# %%
#Write a python program to create agraph to see how the length and width of the SepalLength, SepalWidth, PetalLength, PetalWidth
# are distributed.
new_data.hist(edgecolor="black")
# Out:
# array([[<Axes: title={'center': 'SepalLengthCm'}>,
#         <Axes: title={'center': 'SepalWidthCm'}>],
#        [<Axes: title={'center': 'PetalLengthCm'}>,
#         <Axes: title={'center': 'PetalWidthCm'}>]], dtype=object)

# %%
#Write a Python program to create a graph to find the relationshop between the petal length and width
